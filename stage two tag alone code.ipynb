# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_excel('energydata_complete.xlsx')
ds
# Out:
#                      date  Appliances  lights         T1       RH_1  \
# 0     2016-01-11 17:00:00        60.0    30.0  19.890000  47.596667
# 1     2016-01-11 17:10:00        60.0    30.0  19.890000  46.693333
# 2     2016-01-11 17:20:00        50.0    30.0  19.890000  46.300000
# 3     2016-01-11 17:30:00        50.0    40.0  19.890000  46.066667
# 4     2016-01-11 17:40:00        60.0    40.0  19.890000  46.333333
# ...                   ...         ...     ...        ...        ...
# 19730 2016-05-27 17:20:00       100.0     0.0  25.566667  46.560000
# 19731 2016-05-27 17:30:00        90.0     0.0  25.500000  46.500000
# 19732 2016-05-27 17:40:00       270.0    10.0  25.500000  46.596667
# 19733 2016-05-27 17:50:00       420.0    10.0  25.500000  46.990000
# 19734 2016-05-27 18:00:00       430.0    10.0  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
model = LinearRegression()

# %%
x = pd.DataFrame(ds['T2'])
x
# Out:
#               T2
# 0      19.200000
# 1      19.200000
# 2      19.200000
# 3      19.200000
# 4      19.200000
# ...          ...
# 19730  25.890000
# 19731  25.754000
# 19732  25.628571
# 19733  25.414000
# 19734  25.264286
#
# [19735 rows x 1 columns]

# %%
y = pd.DataFrame(ds['T6'])
y
# Out:
#               T6
# 0       7.026667
# 1       6.833333
# 2       6.560000
# 3       6.433333
# 4       6.366667
# ...          ...
# 19730  24.796667
# 19731  24.196667
# 19732  23.626667
# 19733  22.433333
# 19734  21.026667
#
# [19735 rows x 1 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_preds = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mse = round(mean_squared_error(y_test, y_preds), 3)

# %%
round(mean_absolute_error(y_test, y_preds), 3)
# Out:
# 2.816

# %%
round(np.sqrt(mse), 3)
# Out:
# 3.629

# %%
ds
# Out:
#                      date  Appliances  lights         T1       RH_1  \
# 0     2016-01-11 17:00:00        60.0    30.0  19.890000  47.596667
# 1     2016-01-11 17:10:00        60.0    30.0  19.890000  46.693333
# 2     2016-01-11 17:20:00        50.0    30.0  19.890000  46.300000
# 3     2016-01-11 17:30:00        50.0    40.0  19.890000  46.066667
# 4     2016-01-11 17:40:00        60.0    40.0  19.890000  46.333333
# ...                   ...         ...     ...        ...        ...
# 19730 2016-05-27 17:20:00       100.0     0.0  25.566667  46.560000
# 19731 2016-05-27 17:30:00        90.0     0.0  25.500000  46.500000
# 19732 2016-05-27 17:40:00       270.0    10.0  25.500000  46.596667
# 19733 2016-05-27 17:50:00       420.0    10.0  25.500000  46.990000
# 19734 2016-05-27 18:00:00       430.0    10.0  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
new_ds = ds.drop(['date', 'lights'], axis = 1)

# %%
new_ds = pd.DataFrame(new_ds)
new_ds
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0            60.0  19.890000  47.596667  19.200000  44.790000  19.790000
# 1            60.0  19.890000  46.693333  19.200000  44.722500  19.790000
# 2            50.0  19.890000  46.300000  19.200000  44.626667  19.790000
# 3            50.0  19.890000  46.066667  19.200000  44.590000  19.790000
# 4            60.0  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730       100.0  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731        90.0  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732       270.0  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733       420.0  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734       430.0  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
new_ds = pd.DataFrame(scaler.fit_transform(new_ds), columns = new_ds.columns)

# %%
x = new_ds.drop(['Appliances'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [72], in <cell line: 1>()
# ----> 1 x = new_ds.drop(['Appliances'], axis = 1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...
